# %%
# Built-in library
import itertools
import re
from typing import Any, Optional, Sequence, Union
import warnings

# Standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings("ignore")


# pandas settings
pd.options.display.max_rows = 1_000
pd.options.display.max_columns = 1_000
pd.options.display.max_colwidth = 2_000

# Black code formatter (Optional)
# %load_ext nb_black
# auto reload imports
# %load_ext autoreload
# %autoreload 2

# %%
from bs4 import BeautifulSoup
import requests

# %%
# lets get the url
url_list = [
    "https://www.finelib.com/cities/lagos/business/food/restaurants/page-1",
    "https://www.finelib.com/cities/lagos/business/food/restaurants/page-2",
]

# %%
# simplify the process by writng a function


def get_restaurant_data(*, URL: list) -> pd.DataFrame:
    """
    this function scrapes restaurant information from website and return a cleaned dataframe
    with each restaurant info

    => param:
        URL = list of url for the page to scrape
    """

    # create dictionary with an emty list for the elements
    dict_ = {"restaurant_name": [], "restaurant_address": [], "restaurant_phone_no": []}

    # use for loop to scrape for each url
    for i in URL:
        # make a request from the url
        html_doc = requests.get(i).text

        # initalize the beautiful saoup library
        soup = BeautifulSoup(html_doc, "lxml")

        # getting the table column
        left_column = soup.find(name="div", class_="left-column")

        for idx, data in enumerate(left_column.find_all(name="div", class_="box-682")):
            # getting the infomations
            if idx > 0:
                # getting the name of the restaurant and stor it in the dictionary
                name_ = data.find(name="div", class_="box-headings")
                name = name_.a.text
                dict_["restaurant_name"].append(name)

                # getting the address and store it in the dictionary
                listing_info = data.find(name="div", class_="listing-info-img")
                address = listing_info.find(name="div", class_="cmpny-lstng-1").text
                dict_["restaurant_address"].append(address)

                # getting the restaurant phone number and store it in the dictionary
                phone_no_ = listing_info.find(name="div", class_="tel-no-div")
                phone_no = phone_no_.find(name="div", class_="cmpny-lstng-1").text
                dict_["restaurant_phone_no"].append(phone_no)

    # converting the dictionary to dataframe
    df = pd.DataFrame(dict_)

    return df

# %%
# applying the function
df = get_restaurant_data(URL=url_list)

# %%
df
# Out:
#                             restaurant_name
# 0                  Bernadines Cloud Kitchen  \
# 1                         Abibiz Restaurant
# 2                          Afi's Restaurant
# 3                                   Aldente
# 4                   All Seasons Restaurants
# 5                           Anis Restaurant
# 6                     Appetizers Restaurant
# 7                 Atlantic Bar & Restaurant
# 8                   Ayus Restaurant And Bar
# 9                        Bangkok Restaurant
# 10                                 Barcelos
# 11           Burgy's Fast Food & Restaurant
# 12                   Cal's Place Restaurant
# 13                Cera-Una-Volta Restaurant
# 14                           Chadon Kitchen
# 15              Chardonnay Restaurant & Bar
# 16           Cheesy Restaurant & Snacks Bar
# 17        Chicken Cooking Family Restaurant
# 18                 Chief Delight Restaurant
# 19                 China Restaurant And Bar
# 20            China Town Express Restaurant
# 21            Chinaville Chinese Restaurant
# 22                    Chopsticks Restaurant
# 23             Chow Mein Chinese Restaurant
# 24              Coors Restaurant and Lounge
# 25                    Creek House Brasserie
# 26              Cuisine Africana Restaurant
# 27                  Darling - Ro Restaurant
# 28       Del Pizza Restaurant and Take Away
# 29                          Demmies Delight
# 30          Double Four Restaurant & Eatery
# 31                               Eat It All
# 63                                 13, Deji Olamiji, Gbagada, Kosofe, Lagos, Nigeria
# 64                             Plot 8&9, Block CXLiiiA,, Agungi Lekki Phase 2, Lagos
# 65                                      20, Oladoyinbo Street, Ikeja, Lagos, Nigeria
# 66                   21, Oladimeji Alo Street, Off Freedom Way, Lekki Phase 1, Lagos
# 67                               39, Market Street, Shomolu, Shomolu, Lagos, Nigeria
# 68                                   47CastleRockAvenue, Jakande Osapa London, Lagos
#
#                             restaurant_phone_no
# 0                                 0903 651 7676
# 1                    0803 302 4280, 01 773 1431
# 2                                   01 470 3044
# 3                      01 444 3944, 01 791 2942
# 4                                   01 262 3135
# 5                                   01 263 7556
# 6                                 0803 727 7483
# 7                    0802 327 1564, 01 261 0584
# 8                  0703 381 4662, 0803 316 2543
# 9                  0803 307 7666, 0706 217 3888
# 10                08019 115 1760, 0809 555 4085
# 11                                  01 268 6496
# 12                                  01 471 9686
# 13                                  01 262 0357
# 14                 0802 341 2769, 0802 562 0712
# 15                 0803 322 6955, 0803 322 9701
# 16                                0802 343 2160
# 17                                  01 262 2225
# 18                               +234 1 5872413
# 19                                0806 329 5125
# 20                 0704 095 4224, 0806 454 2582
# 21                 0802 314 1561, 0802 314 1560
# 22                                0803 332 1269
# 23                                0818 734 3782
# 24  0807 521 5266, 0806 801 4593, 0706 612 3210
# 25                 0808 532 1147, 0813 910 5423
# 26                                  01 585 2005
# 27                                  01 263 1414
# 28                                  01 260 2487
# 29                                0802 208 3653
# 30                                0709 800 7317
# 31                                0803 049 1095
# 32                                    01 525213
# 33  0909 868 9016, 0708 144 9307, 0803 332 1269
# 34                                 088034310244
# 35                                0803 347 4840
# 36                    0802 290 4431, 01 7749535
# 37                0803 313 0964,  0803 312 8446
# 38                 0803 725 9431, 0803 194 4299
# 39                     01 473 5320, 01 262 2559
# 40                                0802 346 5491
# 41                 01 290 4332, 01 271 7565 - 7
# 42                 0816 569 6021, 0909 034 9081
# 43                                  01 280 0100
# 44                                0812 111 1222
# 45                  0803 311 2093, 090 407 7928
# 46                 0805 555 5550, 0803 305 3536
# 47                                  01 496 2179
# 48                                  01 268 0697
# 49                                  01 493 9329
# 50                 0810 614 7321, 0708 461 6196
# 51  0807 229 2436, 0807 22 92447, 0807 229 2446
# 52                                0803 301 9943
# 53                                0802 312 3698
# 54                 0809 900 0027, 0809 357 8298
# 55                     01 270 0248, 01 444 8938
# 56                 0816 237 4907, 0818 231 9255
# 57                                0703 017 5434
# 58                 0803 301 9983, 0704 322 2885
# 59                                0803 484 1595
# 60                   0803 400 3755, 01 874 3696
# 61                 0913 427 2579, 0813 368 8523
# 62                 0816 310 5537, 0803 306 5107
# 63                 0809 156 0927, 0802 315 7707
# 64                 0810 744 6322, 0815 905 7235
# 65                 0703 384 2618, 0807 595 3779
# 66                                0906 999 9996
# 67                 0806 209 8455, 0803 488 6706
# 68                                0708 865 9567

# %%
# let save the data to a csv file
df.to_csv("restaurant.csv", index_label="restaurant_id")

# %%
df.shape
# Out:
# (69, 3)
